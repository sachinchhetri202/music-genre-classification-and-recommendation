# %%
import torch, torch.nn.functional as F
import pytorch_lightning as pl

class MusicCNN(pl.LightningModule):
    def __init__(self, lr=1e-3, dropout=.3, n_filters=32):
        super().__init__()
        self.save_hyperparameters()
        self.conv = torch.nn.Sequential(
            torch.nn.Conv2d(1, n_filters, 3, padding=1),  # 128×128
            torch.nn.BatchNorm2d(n_filters), torch.nn.ReLU(), torch.nn.MaxPool2d(2),
            torch.nn.Conv2d(n_filters, n_filters*2, 3, padding=1),  # 64×64
            torch.nn.BatchNorm2d(n_filters*2), torch.nn.ReLU(), torch.nn.MaxPool2d(2)
        )
        self.drop = torch.nn.Dropout(dropout)
        self.fc   = torch.nn.Linear((n_filters*2)*32*32, 10)        # 32×32 flat

    def forward(self, x):
        return self.fc(self.drop(torch.flatten(self.conv(x), 1)))

    def _step(self, batch):
        x, y = batch; logits = self(x)
        loss = F.cross_entropy(logits, y)
        acc  = (logits.argmax(1) == y).float().mean()
        return loss, acc

    def training_step(self, batch, _):  l, a = self._step(batch); self.log_dict({"train_loss": l, "train_acc": a}); return l
    def validation_step(self, batch, _): l, a = self._step(batch); self.log_dict({"val_loss": l, "val_acc": a}, prog_bar=True)
    def configure_optimizers(self):      return torch.optim.Adam(self.parameters(), lr=self.hparams.lr)

# %%
CKPT_PATH = "../notebooks/checkpoints/best_cnn.ckpt"
DEVICE    = "cuda" if torch.cuda.is_available() else "cpu"

model = MusicCNN.load_from_checkpoint(CKPT_PATH).to(DEVICE).eval()
print("Model loaded from:", CKPT_PATH)
# Out:
# Model loaded from: ../notebooks/checkpoints/best_cnn.ckpt

# %%
import torch, librosa, numpy as np, pathlib, random
from scipy.spatial.distance import cdist
import pandas as pd

N_MELS = 128
TIME_FRAMES = 128     # same as training

def preprocess_audio(path, sr=22_050):
    y, _ = librosa.load(path, sr=sr, mono=True)
    mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
    mel  = librosa.power_to_db(mel, ref=np.max)

    # center‑crop / pad to 128 frames
    t = mel.shape[1]
    if t > TIME_FRAMES:
        start = (t - TIME_FRAMES) // 2
        mel = mel[:, start:start + TIME_FRAMES]
    else:
        mel = np.pad(mel, ((0, 0), (0, TIME_FRAMES - t)), "constant")

    return torch.tensor(mel).unsqueeze(0).unsqueeze(0).float()   # (1,1,128,128)

# %%
def get_embedding(x):
    with torch.no_grad():
        feats = model.conv(x)           # output shape (B,C,32,32)
        gap   = torch.nn.functional.adaptive_avg_pool2d(feats, 1).squeeze(-1).squeeze(-1)
    return gap.cpu().numpy()

model.get_embedding = get_embedding   # monkey‑patch for quick use

# %%
TEST_DIR = pathlib.Path("../datasets/GTZAN")       # adjust if needed
bank_paths = random.sample(
    list(TEST_DIR.rglob("*.au")), k=200)           # 200 tracks for quick demo

emb_bank, genres = [], []
for p in bank_paths:
    x = preprocess_audio(p).to(DEVICE)
    emb_bank.append(model.get_embedding(x))
    genres.append(p.parent.name)

emb_bank = np.vstack(emb_bank)
print("Built embedding bank with", len(bank_paths), "tracks")
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03817749 -0.01821899 -0.02246094 ...  0.00189209  0.00866699
#   0.01657104] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03375244 -0.02975464 -0.03762817 ... -0.11248779 -0.1479187
#  -0.17633057] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.12442017 -0.20019531 -0.14730835 ...  0.01928711  0.00610352
#  -0.00448608] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.2953186  0.21789551 0.2272644  ... 0.14749146 0.30541992 0.38446045] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.03161621 0.02642822 0.0246582  ... 0.01641846 0.01043701 0.00692749] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.07189941  0.0133667  -0.0065918  ... -0.05377197 -0.08712769
#  -0.07946777] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04489136  0.07424927  0.06942749 ... -0.01293945 -0.05969238
#  -0.08255005] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04315186  0.09747314  0.05752563 ... -0.03521729  0.00027466
#   0.00268555] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.25927734  0.2713318   0.26333618 ... -0.02270508 -0.01971436
#  -0.01849365] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01702881 -0.00918579 -0.00271606 ... -0.01229858 -0.00866699
#  -0.00552368] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.10452271  0.15914917  0.10348511 ... -0.01296997  0.00421143
#   0.00302124] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.03768921 0.06393433 0.04541016 ... 0.06726074 0.06802368 0.04058838] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01791382  0.00491333 -0.02185059 ... -0.04003906 -0.04852295
#  -0.04107666] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.07522583 -0.07281494 -0.01156616 ... -0.14041138 -0.12265015
#  -0.23773193] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01733398 -0.02090454 -0.01681519 ... -0.10110474 -0.10919189
#  -0.10134888] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.09390259 0.09164429 0.09054565 ... 0.01123047 0.01434326 0.01702881] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.14556885 0.09173584 0.03552246 ... 0.00228882 0.03567505 0.08633423] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.05612183 -0.02548218  0.00076294 ... -0.27697754 -0.26974487
#  -0.34283447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.20825195 -0.16204834 -0.12033081 ... -0.01043701 -0.01095581
#  -0.01226807] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03417969 -0.02215576  0.01190186 ...  0.15057373  0.08218384
#   0.01947021] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02645874 -0.00860596  0.02481079 ...  0.0737915  -0.14147949
#  -0.00082397] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.12936401 -0.14221191 -0.11578369 ... -0.07162476  0.02050781
#   0.02780151] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.10247803 -0.06808472 -0.04293823 ...  0.01733398 -0.00900269
#  -0.05114746] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.037323    0.01690674  0.00811768 ...  0.12271118  0.11727905
#   0.11752319] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.04498291 0.04544067 0.0451355  ... 0.3659973  0.41201782 0.4533081 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01907349 -0.03610229 -0.03683472 ... -0.11407471 -0.12088013
#  -0.11746216] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02020264 -0.03634644 -0.02706909 ...  0.01159668  0.01779175
#   0.04614258] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00915527 -0.00558472 -0.03121948 ...  0.0249939  -0.01477051
#  -0.02624512] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00015259  0.00466919  0.01028442 ... -0.00985718 -0.009552
#  -0.01708984] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.13223267 -0.15200806  0.03436279 ...  0.19424438 -0.02557373
#  -0.10308838] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04806519  0.11572266  0.17010498 ... -0.0383606  -0.08569336
#  -0.0737915 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02935791 -0.03713989 -0.02752686 ... -0.00500488 -0.03240967
#   0.02160645] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.07867432  0.12042236  0.14501953 ... -0.02474976 -0.02694702
#  -0.03384399] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03521729 -0.03540039  0.01885986 ...  0.08673096  0.08920288
#   0.08895874] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03689575 -0.03115845 -0.02194214 ...  0.01855469  0.02093506
#   0.02236938] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.0173645  -0.01702881 -0.01657104 ... -0.05697632 -0.04873657
#  -0.0413208 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.23117065 0.3553772  0.30532837 ... 0.01785278 0.02093506 0.01852417] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.         0.         0.         ... 0.00576782 0.02093506 0.01660156] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.18103027 -0.14593506 -0.11779785 ...  0.31704712  0.13739014
#  -0.08468628] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02023315 -0.03991699 -0.03979492 ...  0.10791016  0.11074829
#   0.0932312 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.07159424  0.07232666  0.07189941 ... -0.1463623  -0.09390259
#  -0.08886719] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.0234375  -0.1100769  -0.11660767 ...  0.10198975  0.06524658
#   0.084198  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.16305542 -0.17230225 -0.16052246 ...  0.03668213 -0.01269531
#  -0.04077148] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00180054  0.02932739  0.00665283 ... -0.12728882 -0.08517456
#  -0.08630371] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00375366  0.00482178 -0.02020264 ...  0.07357788  0.05322266
#   0.0329895 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.06842041 -0.11776733 -0.11746216 ...  0.03613281  0.05218506
#   0.05300903] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01190186 -0.00131226  0.07339478 ...  0.22369385  0.25164795
#   0.26239014] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.09716797 -0.0826416  -0.18780518 ...  0.01223755  0.10797119
#   0.19284058] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.05249023 0.08755493 0.09542847 ... 0.10195923 0.16171265 0.17993164] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.1539917  0.19332886 0.20690918 ... 0.1413269  0.12460327 0.1302185 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.20410156  0.43789673 -0.36032104 ...  0.13781738  0.10992432
#   0.04663086] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00158691 -0.00152588 -0.0118103  ...  0.00793457  0.05090332
#   0.01623535] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01055908 -0.01623535 -0.012146   ...  0.0675354   0.07672119
#   0.07815552] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.06521606 0.0954895  0.08926392 ... 0.10720825 0.20050049 0.1416626 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.22058105 0.2211914  0.22750854 ... 0.14099121 0.0899353  0.10610962] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.1459961  -0.09658813 -0.11193848 ...  0.02349854  0.06124878
#   0.06143188] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.10235596 -0.06472778 -0.00518799 ... -0.1036377  -0.08279419
#  -0.06362915] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00973511  0.00488281 -0.01168823 ...  0.08969116 -0.00772095
#  -0.03738403] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.16659546 -0.23223877 -0.2239685  ... -0.06652832 -0.06881714
#  -0.06912231] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.21246338  0.31881714  0.17388916 ... -0.03594971 -0.04187012
#  -0.02597046] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00958252  0.00186157  0.21276855 ...  0.2775879   0.1550293
#   0.17849731] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01254272  0.00994873 -0.00552368 ... -0.5603943  -0.35263062
#  -0.0322876 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04193115  0.06799316  0.05114746 ...  0.23345947  0.12826538
#  -0.0302124 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.13345337 -0.12698364 -0.12200928 ...  0.02294922  0.02658081
#   0.03622437] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.08126831  0.03677368  0.02056885 ... -0.12475586 -0.08557129
#  -0.05020142] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.23965454  0.25027466  0.23980713 ... -0.05026245  0.06378174
#   0.06427002] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.0461731   0.05691528  0.00158691 ... -0.05786133 -0.10861206
#  -0.12380981] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01882935  0.03295898  0.03451538 ... -0.07113647 -0.05267334
#  -0.01193237] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04116821 -0.0506897  -0.07846069 ...  0.17160034  0.13851929
#   0.05413818] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.0350647   0.03735352  0.03372192 ...  0.02325439 -0.00863647
#  -0.01925659] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.20800781  0.17477417  0.1178894  ... -0.00463867  0.03137207
#   0.01412964] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.36239624 0.6494751  0.6317444  ... 0.04336548 0.0557251  0.05700684] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00964355 -0.01760864 -0.03842163 ...  0.02990723  0.06143188
#   0.08258057] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.02148438  0.003479   -0.00161743 ... -0.19900513 -0.03552246
#   0.10549927] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00497437  0.00491333  0.00244141 ...  0.00079346 -0.00396729
#  -0.00378418] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04229736 -0.05657959 -0.12426758 ...  0.046875    0.05056763
#   0.02993774] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00521851  0.00061035  0.0043335  ... -0.0149231  -0.01800537
#  -0.02783203] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.24682617 0.1798706  0.21160889 ... 0.13964844 0.14328003 0.1458435 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02023315 -0.05187988 -0.07672119 ...  0.01208496  0.01571655
#   0.01812744] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.09124756 -0.06356812 -0.04788208 ...  0.12573242  0.08944702
#   0.07394409] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.06201172 -0.0647583   0.01269531 ...  0.17086792  0.18267822
#   0.17208862] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01907349  0.01107788 -0.00460815 ...  0.18780518  0.21450806
#   0.2159729 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.24325562 0.39767456 0.3430786  ... 0.31188965 0.33831787 0.17007446] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.05828857  0.01071167  0.09915161 ...  0.03128052 -0.01806641
#  -0.00238037] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.14147949 -0.05548096  0.10794067 ...  0.01657104  0.17730713
#   0.14160156] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.02487183  0.0380249   0.02770996 ... -0.02423096 -0.02633667
#  -0.03213501] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03363037 -0.03662109 -0.14022827 ...  0.0067749  -0.0802002
#  -0.14544678] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00057983 -0.0017395  -0.00259399 ... -0.00448608 -0.00271606
#  -0.00289917] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.18231201 -0.18560791 -0.16290283 ... -0.10397339 -0.02603149
#   0.0085144 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.1164856  -0.08837891 -0.0050354  ... -0.22717285 -0.23620605
#  -0.18695068] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04498291 -0.22296143 -0.1835022  ...  0.07702637  0.19641113
#   0.22677612] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.36514282  0.5903015   0.5239563  ... -0.01025391 -0.01419067
#  -0.00646973] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.19573975 -0.21173096 -0.22302246 ... -0.21466064 -0.19448853
#  -0.1517334 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.23739624  0.36120605  0.30667114 ...  0.17504883  0.01113892
#  -0.18429565] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04263306 -0.01522827 -0.02587891 ... -0.10150146 -0.10940552
#  -0.11834717] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.3352661  0.1633606  0.08322144 ... 0.06304932 0.16360474 0.1465149 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04281616 -0.06454468 -0.05288696 ... -0.00152588 -0.00405884
#  -0.00592041] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.03549194 -0.12539673 -0.07580566 ...  0.10067749 -0.04244995
#   0.06140137] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.25305176 -0.41104126 -0.35287476 ... -0.17889404 -0.12127686
#  -0.05593872] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.35983276 0.4281311  0.36676025 ... 0.11392212 0.11721802 0.10369873] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.1300354   0.15908813  0.09783936 ... -0.18374634 -0.22894287
#  -0.19534302] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.02630615  0.02297974  0.01797485 ...  0.01303101  0.00576782
#  -0.00183105] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.06576538 0.23931885 0.17428589 ... 0.21966553 0.13690186 0.08480835] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00262451 -0.00375366 -0.00387573 ... -0.09399414 -0.09292603
#  -0.08978271] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.02633667  0.04815674  0.05267334 ... -0.12530518 -0.14364624
#  -0.11053467] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.09475708 -0.05712891
#  -0.07150269] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04077148  0.06689453  0.06573486 ... -0.23034668 -0.22885132
#  -0.22930908] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02224731 -0.0241394  -0.02676392 ... -0.1505127  -0.17611694
#  -0.17214966] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.2616577  0.26055908 0.25509644 ... 0.00842285 0.00823975 0.00164795] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.10986328 -0.0760498  -0.07336426 ... -0.19326782 -0.26968384
#  -0.18850708] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.21359253 -0.35723877 -0.31430054 ... -0.0574646  -0.01867676
#  -0.01022339] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.09863281  0.15170288  0.12884521 ... -0.06152344 -0.06439209
#  -0.06393433] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01470947 -0.02044678 -0.0173645  ... -0.056427   -0.06686401
#  -0.06759644] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.18252563  0.04763794  0.05682373 ... -0.07180786  0.0012207
#  -0.0020752 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00384521  0.02346802  0.07144165 ...  0.04241943 -0.10992432
#  -0.07177734] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00747681 -0.00967407 -0.01113892 ...  0.01791382  0.01971436
#   0.01654053] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04043579 -0.11618042  0.04278564 ...  0.655365    0.592041
#   0.6399536 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.0005188   0.00067139 -0.00146484 ... -0.02835083 -0.02896118
#  -0.02661133] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.06140137 -0.03152466 -0.00521851 ...  0.01834106  0.00869751
#   0.00863647] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.0581665   0.01168823  0.03125    ... -0.08297729 -0.07485962
#  -0.0333252 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.06484985 -0.10720825 -0.10943604 ...  0.00100708  0.00100708
#   0.00109863] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[3.0517578e-05 1.8920898e-02 2.6275635e-02 ... 7.5805664e-02 5.7708740e-02
#  4.6691895e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.27172852 0.29891968 0.31332397 ... 0.03329468 0.03466797 0.03259277] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.072052   -0.06845093 -0.06713867 ...  0.21130371  0.19897461
#   0.18203735] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.08755493 -0.14620972 -0.16326904 ...  0.4052124   0.58755493
#   0.28518677] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.07858276 -0.1638794  -0.11288452 ... -0.04620361 -0.06542969
#  -0.06655884] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.00479126 0.00488281 0.0045166  ... 0.01306152 0.01400757 0.01345825] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03292847  0.30993652  0.48135376 ... -0.18603516 -0.01733398
#   0.07772827] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03820801 -0.06240845 -0.06326294 ...  0.03881836  0.02508545
#   0.00601196] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04074097  0.04595947  0.03143311 ...  0.0904541  -0.03186035
#  -0.05340576] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.09933472 0.18466187 0.07312012 ... 0.06643677 0.11355591 0.12359619] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.12133789  0.01956177  0.0484314  ...  0.01849365  0.00595093
#  -0.0322876 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.06842041 -0.05499268 -0.00134277 ... -0.07080078 -0.17538452
#  -0.22354126] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00064087 -0.00097656  0.00247192 ... -0.01867676  0.02722168
#  -0.03652954] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00378418  0.04263306  0.04504395 ... -0.31472778 -0.2567749
#  -0.3123474 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01983643 -0.0574646  -0.09024048 ...  0.09188843  0.10098267
#   0.09979248] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00991821 -0.03305054 -0.0279541  ... -0.12088013 -0.15499878
#  -0.11825562] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.0100708  0.06564331 0.06677246 ... 0.01190186 0.02789307 0.04650879] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.06588745  0.10037231  0.08508301 ... -0.03790283 -0.04553223
#  -0.04312134] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.06652832  0.16467285  0.2319336  ...  0.00335693 -0.00650024
#  -0.00723267] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.19454956 -0.2170105  -0.23977661 ... -0.00567627 -0.0135498
#  -0.00457764] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.3501892  0.34851074 0.32894897 ... 0.1505127  0.17098999 0.07476807] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.09228516 -0.20037842 -0.27676392 ... -0.1456604  -0.30737305
#  -0.37786865] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.04678345 0.07421875 0.07055664 ... 0.19915771 0.21505737 0.2149353 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.03982544  0.04125977  0.03393555 ... -0.0546875  -0.04458618
#  -0.04180908] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.07617188 -0.05743408 -0.02032471 ...  0.3598938  -0.03610229
# ...
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.05349731 -0.08444214 -0.07592773 ... -0.01257324 -0.01620483
#  -0.01782227] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.0017395   0.00390625  0.00375366 ... -0.08197021 -0.14053345
#  -0.17556763] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.05926514  0.06332397  0.03329468 ... -0.08285522  0.01535034
#   0.11514282] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.07824707 -0.15307617 -0.13339233 ... -0.03494263 -0.00942993
#   0.01477051] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.02072144 0.04492188 0.05422974 ... 0.06912231 0.08303833 0.08572388] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.14013672 -0.14840698 -0.06219482 ...  0.07339478  0.05938721
#   0.05514526] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03121948 -0.06448364 -0.05792236 ... -0.08337402 -0.10443115
#  -0.10617065] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.08584595 -0.09381104 -0.21917725 ...  0.16452026  0.12005615
#   0.1569519 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03408813 -0.10879517  0.02957153 ...  0.0513916   0.22744751
#   0.1673584 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.11386108 -0.15759277 -0.08456421 ... -0.4359436  -0.4033203
#  -0.1847229 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.07894897  0.13638306  0.13336182 ... -0.01293945 -0.00521851
#   0.00741577] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.06274414 0.08099365 0.07693481 ... 0.01312256 0.00787354 0.01483154] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.04248047 -0.10879517  0.07177734 ...  0.01757812  0.05621338
#   0.08587646] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.00332642 -0.01135254 -0.00799561 ...  0.00863647  0.01904297
#   0.02990723] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.02862549  0.01321411 -0.02185059 ... -0.00158691  0.00186157
#   0.00491333] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03015137 -0.0453186  -0.04034424 ...  0.06164551  0.07870483
#   0.08056641] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00396729  0.00012207  0.0166626  ... -0.03201294 -0.02890015
#  -0.03329468] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01974487  0.0213623   0.0222168  ... -0.13058472 -0.08270264
#  -0.05801392] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.04135132  0.04818726  0.05679321 ... -0.05780029 -0.01217651
#  -0.01144409] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.03118896  0.06994629 -0.09649658 ... -0.0272522  -0.02200317
#  -0.03103638] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.11471558 0.31384277 0.43185425 ... 0.00418091 0.00289917 0.00631714] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01818848  0.01361084  0.01654053 ... -0.03775024 -0.03204346
#  -0.09603882] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.01681519 -0.02255249  0.02285767 ... -0.10302734 -0.10443115
#  -0.10949707] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.07998657 -0.09335327 -0.0329895  ... -0.06915283 -0.06433105
#  -0.0581665 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.10241699 -0.06164551 -0.11993408 ...  0.0145874   0.07440186
#  -0.00054932] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.62197876  0.526947    0.5707092  ... -0.01599121  0.18591309
#   0.37527466] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.07824707  0.07504272  0.07333374 ... -0.00839233 -0.00042725
#   0.01071167] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00079346  0.0017395   0.00183105 ... -0.00402832 -0.00448608
#  -0.00424194] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.5274658  -0.49420166 -0.2960205  ...  0.04638672  0.08068848
#   0.10092163] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.09091187 -0.10177612 -0.09683228 ...  0.15197754  0.15585327
#   0.14904785] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.03479004  0.08447266  0.0668335  ... -0.10333252 -0.12298584
#  -0.15881348] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.0128479   0.02072144  0.01940918 ... -0.02362061 -0.07141113
#  -0.09091187] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.06283569 0.08822632 0.08084106 ... 0.22628784 0.29864502 0.20721436] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.02429199 -0.02975464 -0.00961304 ...  0.13458252  0.0619812
#  -0.00091553] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.28155518 -0.3609314  -0.4019165  ...  0.03143311  0.02233887
#   0.00592041] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.00564575  0.00817871  0.00622559 ... -0.00527954 -0.00521851
#  -0.00454712] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.01455688 -0.06048584 -0.02310181 ...  0.15847778  0.17572021
#   0.04360962] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.10247803 0.08059692 0.10037231 ... 0.08895874 0.11795044 0.16305542] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.12008667 0.17089844 0.11740112 ... 0.059021   0.06976318 0.13381958] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.2119751  -0.0675354  -0.18411255 ... -0.50982666 -0.85583496
#  -0.37353516] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[-0.03082275 -0.03540039 -0.03076172 ...  0.00561523  0.00332642
#  -0.00238037] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 2.5878906e-02 -1.2207031e-04  3.6834717e-02 ...  3.9044189e-01
#   2.3257446e-01  2.8952026e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.06192017  0.01989746 -0.03140259 ...  0.11914062  0.13412476
#   0.10879517] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.15924072  0.11972046  0.1126709  ... -0.07067871 -0.01205444
#   0.01016235] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.0222168   0.0296936   0.03231812 ...  0.04040527 -0.0479126
#  -0.12384033] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.10076904  0.15240479  0.12155151 ... -0.00024414  0.00830078
#   0.03182983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# Built embedding bank with 200 tracks
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.01068115 0.03204346 0.05667114 ... 0.0173645  0.01751709 0.01815796] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[ 0.1643982   0.04977417  0.08407593 ... -0.11746216 -0.24118042
#  -0.17047119] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)

# %%
def predict_and_recommend(wav_path, k=5):
    x = preprocess_audio(wav_path).to(DEVICE)
    with torch.no_grad():
        logits = model(x)
        pred   = logits.argmax(1).item()
        idx2genre = sorted({p.parent.name for p in bank_paths})
        genre  = idx2genre[pred]

    seed_emb = model.get_embedding(x)
    dists    = cdist(seed_emb, emb_bank, metric="cosine").flatten()
    idxs     = dists.argsort()[:k]

    recs = [(bank_paths[i].name, genres[i], dists[i]) for i in idxs]
    return genre, recs

# %%
sample_clip = "../datasets/GTZAN/disco/disco.00008.au"   # pick any file
genre, recs = predict_and_recommend(sample_clip, k=5)

print("Input clip:", pathlib.Path(sample_clip).name)
print("Predicted genre:", genre, "\n\nTop‑5 similar tracks:")
df = pd.DataFrame(recs, columns=["file", "genre", "cosine_dist"])

display(df)
# Out:
# Input clip: disco.00008.au
# Predicted genre: disco
#
# Top‑5 similar tracks:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_13428\2297023653.py:10: FutureWarning: Pass y=[0.02011108 0.02133179 0.0241394  ... 0.32821655 0.18182373 0.07104492] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel  = librosa.feature.melspectrogram(y, sr=sr, n_mels=N_MELS)
#                file    genre  cosine_dist
# 0    disco.00012.au    disco     0.002541
# 1      pop.00019.au      pop     0.002703
# 2     rock.00075.au     rock     0.003760
# 3   hiphop.00025.au   hiphop     0.004357
# 4  country.00041.au  country     0.004979
